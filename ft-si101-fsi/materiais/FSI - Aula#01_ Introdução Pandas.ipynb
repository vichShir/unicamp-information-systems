# %%
import pandas as pd
import seaborn as sn

workbook = pd.DataFrame(
    {
        "idades" : [8, 18, 21.5, 32]
    }
)

workbook
# Out:
#    idades
# 0     8.0
# 1    18.0
# 2    21.5
# 3    32.0

# %%
workbook.idades.mean()
# Out:
# <bound method Series.mean of 0     8.0
# 1    18.0
# 2    21.5
# 3    32.0
# Name: idades, dtype: float64>

# %%
workbook.idades.describe()
# Out:
# count     4.000000
# mean     19.875000
# std       9.902651
# min       8.000000
# 25%      15.500000
# 50%      19.750000
# 75%      24.125000
# max      32.000000
# Name: idades, dtype: float64
