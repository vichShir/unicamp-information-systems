# %% [markdown]
# #Análise Banco de Dados - Tempo em Seattle

# %% [markdown]
# * head()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd

weather_reviews = pd.read_csv("drive/My Drive/Colab Datasets/seattleWeather_1948-2017.csv")
weather_reviews.head(14)
# Out:
#           DATE  PRCP  TMAX  TMIN   RAIN
# 0   1948-01-01  0.47    51    42   True
# 1   1948-01-02  0.59    45    36   True
# 2   1948-01-03  0.42    45    35   True
# 3   1948-01-04  0.31    45    34   True
# 4   1948-01-05  0.17    45    32   True
# 5   1948-01-06  0.44    48    39   True
# 6   1948-01-07  0.41    50    40   True
# 7   1948-01-08  0.04    48    35   True
# 8   1948-01-09  0.12    50    31   True
# 9   1948-01-10  0.74    43    34   True
# 10  1948-01-11  0.01    42    32   True
# 11  1948-01-12  0.00    41    26  False
# 12  1948-01-13  0.00    45    29  False
# 13  1948-01-14  0.00    38    26  False

# %% [markdown]
# * Describe()

# %%
weather_reviews.TMAX.describe()
# Out:
# count    25551.000000
# mean        59.544206
# std         12.772984
# min          4.000000
# 25%         50.000000
# 50%         58.000000
# 75%         69.000000
# max        103.000000
# Name: TMAX, dtype: float64

# %% [markdown]
# * value_counts()

# %%
weather_reviews.TMAX.value_counts().sort_index()
# Out:
# 4      1
# 16     1
# 17     1
# 18     2
# 19     1
#       ..
# 97     5
# 98     6
# 99     3
# 100    1
# 103    1
# Name: TMAX, Length: 87, dtype: int64

# %% [markdown]
# * bar()

# %%
weather_reviews.TMAX.value_counts().sort_index().plot.bar()

# %%
weather_reviews.TMAX.value_counts().sort_index().plot.line()

# %% [markdown]
# * hist()

# %%
weather_reviews.TMAX.plot.hist()

# %% [markdown]
# * scatter()

# %%
weather_reviews.plot.scatter(x='PRCP', y='TMAX')

# %% [markdown]
# * hexbin()

# %%
weather_reviews.plot.hexbin(x='PRCP', y='TMAX', gridsize=20)

# %%
weather_reviews.plot.line()

# %%
weather_reviews.TMAX.value_counts().sort_index().plot.line()

# %%
weather_reviews[weather_reviews.RAIN == False].TMAX.value_counts().sort_index().plot.line()

# %%
weather_reviews[weather_reviews.RAIN == True].TMAX.value_counts().sort_index().plot.line()
