# %% [markdown]
# #Análise Banco de Dados - Tempo em Seattle

# %% [markdown]
# * head()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

weather_reviews = pd.read_csv("drive/My Drive/Colab Datasets/seattleWeather_1948-2017.csv")
weather_reviews.head()
# Out:
#          DATE  PRCP  TMAX  TMIN  RAIN
# 0  1948-01-01  0.47    51    42  True
# 1  1948-01-02  0.59    45    36  True
# 2  1948-01-03  0.42    45    35  True
# 3  1948-01-04  0.31    45    34  True
# 4  1948-01-05  0.17    45    32  True

# %% [markdown]
# * info()

# %%
weather_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25551 entries, 0 to 25550
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    25551 non-null  object
#  1   PRCP    25548 non-null  float64
#  2   TMAX    25551 non-null  int64
#  3   TMIN    25551 non-null  int64
#  4   RAIN    25548 non-null  object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 998.2+ KB

# %% [markdown]
# * countplot()

# %%
sns.countplot(x='RAIN', data = weather_reviews)

# %%
weather_reviews.RAIN.describe()
# Out:
# count     25548
# unique        2
# top       False
# freq      14648
# Name: RAIN, dtype: object

# %% [markdown]
# # factorplot()

# %%
sns.factorplot(x='TMAX', col='RAIN', kind='count', data = weather_reviews)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='TMIN', col='RAIN', kind='box', data = weather_reviews)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='PRCP', col='RAIN', kind='violin', data = weather_reviews)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
